# %% [markdown]
# # Entrez-direct tool for searching the NCBI database
#
# This link has instructions for installation and searching the databases.
# https://www.ncbi.nlm.nih.gov/books/NBK179288/

# %% [markdown]
# The first step is defining the search terms:
#
# "Saccharum"[Organism] AND "biomol rna"[Properties] AND ("pathogen" OR "microbial" OR "microbiome" OR "fungus" OR "bacteria" OR "virus" OR "mycorrhizal" OR "endophyte" OR "rhizosphere")

# %%
# Encoded the query into URL terms:
# More information here https://www.ncbi.nlm.nih.gov/books/NBK25498/ 

import os

os.system('curl -X POST "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"  -d "db=sra&term=Saccharum%5BOrganism%5D%20AND%20%22biomol%20rna%22%5BProperties%5D%20AND%20(pathogen%20OR%20microbial%20OR%20microbiome%20OR%20fungus%20OR%20bacteria%20OR%20virus%20OR%20mycorrhiza%20OR%20endophyte%20OR%20rhizosphere)&retmax=400" > sugarcane_esearch_ids.txt')
# Out:
# sh: 1: curl: not found
# 32512

# %% [markdown]
# # Convert XML output into CSV - esummary

# %%
import pandas as pd
import xml.etree.ElementTree as ET
from html import unescape

# %%
def parse_docsum(docsum):
    data = {}
    
    # Get the ID
    data['Id'] = docsum.findtext('Id')

    # Loop through all <Item> tags
    for item in docsum.findall('Item'):
        name = item.attrib.get('Name')
        value = item.text

        if name == 'ExpXml' and value:
            # Unescape and parse the embedded XML
            # exp_xml = ET.fromstring(unescape(value))
            exp_xml = ET.fromstring(f"<root>{unescape(value)}</root>")
            
            data['Title'] = exp_xml.findtext('.//Title')
            data['Instrument'] = exp_xml.find('.//Platform').attrib.get('instrument_model')
            stats = exp_xml.find('.//Statistics')
            data['Total Runs'] = stats.attrib.get('total_runs')
            data['Total Spots'] = stats.attrib.get('total_spots')
            data['Total Bases'] = stats.attrib.get('total_bases')
            data['Total Size'] = stats.attrib.get('total_size')

            submitter = exp_xml.find('.//Submitter')
            data['Submitter'] = submitter.attrib.get('acc')
            data['Center'] = submitter.attrib.get('center_name')
            data['Contact'] = submitter.attrib.get('contact_name')

            exp = exp_xml.find('.//Experiment')
            data['Experiment'] = exp.attrib.get('acc')

            study = exp_xml.find('.//Study')
            data['Study'] = study.attrib.get('acc')

            organism = exp_xml.find('.//Organism')
            data['Organism'] = organism.attrib.get('ScientificName')

            sample = exp_xml.find('.//Sample')
            data['Sample'] = sample.attrib.get('acc')

            lib = exp_xml.find('.//Library_descriptor')
            data['Library Strategy'] = lib.findtext('.//LIBRARY_STRATEGY')
            data['Library Source'] = lib.findtext('.//LIBRARY_SOURCE')
            data['Library Selection'] = lib.findtext('.//LIBRARY_SELECTION')
            data['Library Layout'] = 'SINGLE' if lib.find('.//SINGLE') is not None else 'PAIRED'

            data['Bioproject'] = exp_xml.findtext('.//Bioproject')
            data['Biosample'] = exp_xml.findtext('.//Biosample')

        elif name == 'Runs' and value:
            # run_xml = ET.fromstring(unescape(value))
            run_xml = ET.fromstring(f"<root>{unescape(value)}</root>")

            data['Run Accession'] = run_xml.attrib.get('acc')
            data['Run Spots'] = run_xml.attrib.get('total_spots')
            data['Run Bases'] = run_xml.attrib.get('total_bases')

        elif name == 'CreateDate':
            data['Create Date'] = value
        elif name == 'UpdateDate':
            data['Update Date'] = value

    return data

# %%
def xml_to_dataframe(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    records = [parse_docsum(docsum) for docsum in root.findall('DocSum')]
    df = pd.DataFrame(records)
    return df

# %%
df = xml_to_dataframe("sorghum_project_list_7November2025")
df
# Out:
#            Id                                              Title  \
# 0    35954038  Metabolomic and Transcriptomic Analysis of Dro...
# 1    35954037  Metabolomic and Transcriptomic Analysis of Dro...
# 2    35954036  Metabolomic and Transcriptomic Analysis of Dro...
# 3    35954035  Metabolomic and Transcriptomic Analysis of Dro...
# 4    35954034  Metabolomic and Transcriptomic Analysis of Dro...
# ..        ...                                                ...
# 456    734680  Drought-responsive small RNAs in Sorghum bicol...
# 457    734679  Drought-responsive small RNAs in Sorghum bicol...
# 458    734678  Drought-responsive small RNAs in Sorghum bicol...
# 459    734677  Drought-responsive small RNAs in Sorghum bicol...
# 460    120199                         GSM822664: sorghum_drought
#
#                        Instrument Total Runs Total Spots Total Bases  \
# 0           Illumina NovaSeq 6000          1    20441684  6119255806
# 1           Illumina NovaSeq 6000          1    20358514  6095948666
# 2           Illumina NovaSeq 6000          1    20745508  6210300618
# 3           Illumina NovaSeq 6000          1    19444175  5820262192
# 4           Illumina NovaSeq 6000          1    21674601  6488969244
# ..                            ...        ...         ...         ...
# 456  Illumina Genome Analyzer IIx          1    19821595   693755825
# 457  Illumina Genome Analyzer IIx          1    22878203   800737105
# 458  Illumina Genome Analyzer IIx          1    21740738   760925830
# 459  Illumina Genome Analyzer IIx          1    18890943   661183005
# 460      Illumina Genome Analyzer          1    31099345  1243973800
#
#      Total Size   Submitter  \
# 0    1882919550  SRA2001949
# 1    1851542395  SRA2001949
# 2    1893113189  SRA2001949
# 3    1787584416  SRA2001949
# 4    1982273902  SRA2001949
# ..          ...         ...
# 456   374391067   ERA208090
# 457   449970914   ERA208090
# 458   415274994   ERA208090
# 459   373368895   ERA208090
# 460   790526317   SRA047355
#
#                                                 Center  \
# 0           Xingjiang Academy of Agricultural Sciences
# 1           Xingjiang Academy of Agricultural Sciences
# 2           Xingjiang Academy of Agricultural Sciences
# 3           Xingjiang Academy of Agricultural Sciences
# 4           Xingjiang Academy of Agricultural Sciences
# ..                                                 ...
# 456  National Bureau of Plant Genetic Resources, Ne...
# 457  National Bureau of Plant Genetic Resources, Ne...
# 458  National Bureau of Plant Genetic Resources, Ne...
# 459  National Bureau of Plant Genetic Resources, Ne...
# 460                                                GEO
#
#                                                Contact  ...  Library Source  \
# 0                                               YUE Li  ...  TRANSCRIPTOMIC
# 1                                               YUE Li  ...  TRANSCRIPTOMIC
# 2                                               YUE Li  ...  TRANSCRIPTOMIC
# 3                                               YUE Li  ...  TRANSCRIPTOMIC
# 4                                               YUE Li  ...  TRANSCRIPTOMIC
# ..                                                 ...  ...             ...
# 456                                       ArrayExpress  ...  TRANSCRIPTOMIC
# 457                                       ArrayExpress  ...  TRANSCRIPTOMIC
# 458                                       ArrayExpress  ...  TRANSCRIPTOMIC
# 459                                       ArrayExpress  ...  TRANSCRIPTOMIC
# 460  Gene Expression Omnibus (GEO), NCBI, NLM, NIH,...  ...  TRANSCRIPTOMIC
#
#     Library Selection Library Layout    Bioproject     Biosample  \
# 0              RANDOM         PAIRED  PRJNA1180449  SAMN44415016
# 1              RANDOM         PAIRED  PRJNA1180449  SAMN44415015
# 2              RANDOM         PAIRED  PRJNA1180449  SAMN44415014
# 3              RANDOM         PAIRED  PRJNA1180449  SAMN44415013
# 4              RANDOM         PAIRED  PRJNA1180449  SAMN44415012
# ..                ...            ...           ...           ...
# 456            RANDOM         SINGLE     PRJEB1849  SAMEA2065629
# 457            RANDOM         SINGLE     PRJEB1849  SAMEA2065628
# 458            RANDOM         SINGLE     PRJEB1849  SAMEA1969582
# 459            RANDOM         SINGLE     PRJEB1849  SAMEA2065467
# 460             other         SINGLE   PRJNA149413  SAMN00744436
#
#     Run Accession Run Spots Run Bases Create Date Update Date
# 0            None      None      None  2024/11/05  2024/11/05
# 1            None      None      None  2024/11/05  2024/11/05
# 2            None      None      None  2024/11/05  2024/11/05
# 3            None      None      None  2024/11/05  2024/11/05
# 4            None      None      None  2024/11/05  2024/11/05
# ..            ...       ...       ...         ...         ...
# 456          None      None      None  2014/05/14  2014/08/12
# 457          None      None      None  2014/05/14  2014/08/12
# 458          None      None      None  2014/05/14  2014/08/12
# 459          None      None      None  2014/05/14  2014/08/12
# 460          None      None      None  2015/10/25  2014/06/17
#
# [461 rows x 25 columns]

# %%
df.to_csv("sorghum_project_list_7November2025.csv", index=False)

# %% [markdown]
# # Transform XML to df - efetch
#
# it has the run accession

# %%
for pkg in root.findall('EXPERIMENT_PACKAGE'):
    print(pkg.find("SAMPLE").attrib.get("LIBRARY_LAYOUT"))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
import xml.etree.ElementTree as ET
import pandas as pd

# Load XML
tree = ET.parse('sorghum_runs.xml')
root = tree.getroot()

# List to hold records
data = []

# Loop through each EXPERIMENT_PACKAGE
for pkg in root.findall('EXPERIMENT_PACKAGE'):
    experiment = pkg.find('EXPERIMENT')
    run_set = pkg.find('RUN_SET')

    exp_id = experiment.attrib.get('accession')
    exp_alias = experiment.attrib.get('alias')
    title = experiment.findtext('TITLE')
    study_acc = experiment.find('STUDY_REF').attrib.get('accession')
    design_desc = experiment.findtext('DESIGN/DESIGN_DESCRIPTION')
    sample_acc = experiment.find('DESIGN/SAMPLE_DESCRIPTOR').attrib.get('accession')
    library_strategy = experiment.findtext('DESIGN/LIBRARY_DESCRIPTOR/LIBRARY_STRATEGY')
    instrument_model = experiment.findtext('PLATFORM/ILLUMINA/INSTRUMENT_MODEL')

    # Get library layout: SINGLE or PAIRED
    layout_elem = experiment.find('DESIGN/LIBRARY_DESCRIPTOR/LIBRARY_LAYOUT')
    if layout_elem is not None:
        if layout_elem.find('SINGLE') is not None:
            library_layout = 'SINGLE'
        elif layout_elem.find('PAIRED') is not None:
            library_layout = 'PAIRED'
        else:
            library_layout = 'UNKNOWN'
    else:
        library_layout = 'UNKNOWN'

    run = run_set.find('RUN') if run_set is not None else None
    run_acc = run.attrib.get('accession') if run is not None else None
    total_spots = run.attrib.get('total_spots') if run is not None else None
    total_bases = run.attrib.get('total_bases') if run is not None else None

    data.append({
        'experiment_accession': exp_id,
        'experiment_alias': exp_alias,
        'title': title,
        'study_accession': study_acc,
        'design_description': design_desc,
        'sample_accession': sample_acc,
        'library_strategy': library_strategy,
        'library_layout': library_layout,
        'instrument_model': instrument_model,
        'run_accession': run_acc,
        'total_spots': total_spots,
        'total_bases': total_bases
    })

# Create DataFrame
df = pd.DataFrame(data)
print(df.head())
# Out:
#   experiment_accession experiment_alias  \
# 0          SRX26611583           GL98D1
# 1          SRX26611582           GL98C3
# 2          SRX26611581           GL98C2
# 3          SRX26611580           GL98C1
# 4          SRX26611579          GL220B3
#
#                                                title study_accession  \
# 0  Metabolomic and Transcriptomic Analysis of Dro...       SRP543294
# 1  Metabolomic and Transcriptomic Analysis of Dro...       SRP543294
# 2  Metabolomic and Transcriptomic Analysis of Dro...       SRP543294
# 3  Metabolomic and Transcriptomic Analysis of Dro...       SRP543294
# 4  Metabolomic and Transcriptomic Analysis of Dro...       SRP543294
#
#   design_description sample_accession library_strategy library_layout  \
# 0      treated seeds      SRS23110265          RNA-Seq         PAIRED
# 1      treated seeds      SRS23110264          RNA-Seq         PAIRED
# 2      treated seeds      SRS23110263          RNA-Seq         PAIRED
# 3      treated seeds      SRS23110262          RNA-Seq         PAIRED
# 4      treated seeds      SRS23110261          RNA-Seq         PAIRED
#
#         instrument_model run_accession total_spots total_bases
# 0  Illumina NovaSeq 6000   SRR31231318    20441684  6119255806
# 1  Illumina NovaSeq 6000   SRR31231319    20358514  6095948666
# 2  Illumina NovaSeq 6000   SRR31231320    20745508  6210300618
# 3  Illumina NovaSeq 6000   SRR31231321    19444175  5820262192
# 4  Illumina NovaSeq 6000   SRR31231322    21674601  6488969244

# %%
# Remove 51 miRNA-Seq projects
print(df["library_strategy"].value_counts())
df = df[df["library_strategy"] != 'OTHER']
df = df[df["library_strategy"] != 'ssRNA-seq']
df = df[df["library_strategy"] != 'miRNA-Seq']
# Out:
# library_strategy
# RNA-Seq      430
# OTHER         12
# ssRNA-seq      9
# ncRNA-Seq      6
# miRNA-Seq      4
# Name: count, dtype: int64

# %%
df.to_csv("sorghum_runs_cleaned.csv", index=False)

# %% [markdown]
# # Merge run and project information

# %%
import pandas as pd

df1 = pd.read_csv("sorghum_runs_cleaned.csv")
df2 = pd.read_csv("sorghum_project_list_7November2025.csv")

# %%
joined = df1.merge(df2, right_on='Experiment', left_on="experiment_accession", how='left')
joined = joined.drop(columns=['experiment_accession', 'experiment_alias', 'study_accession', 'instrument_model', 'total_spots', 'title', "Title", 'library_strategy', 'library_layout',
       'total_bases', 'Id', 'Instrument', 'Total Runs', 'Total Spots',
       'Total Bases'])
joined.to_csv("sorghum_runs_projects_merged_full.csv", index=False)

joined.columns
# Out:
# Index(['design_description', 'sample_accession', 'run_accession', 'Total Size',
#        'Submitter', 'Center', 'Contact', 'Experiment', 'Study', 'Organism',
#        'Sample', 'Library Strategy', 'Library Source', 'Library Selection',
#        'Library Layout', 'Bioproject', 'Biosample', 'Run Accession',
#        'Run Spots', 'Run Bases', 'Create Date', 'Update Date'],
#       dtype='object')

# %%
joined
# Out:
#                                     design_description sample_accession  \
# 0                                        treated seeds      SRS23110265
# 1                                        treated seeds      SRS23110264
# 2                                        treated seeds      SRS23110263
# 3                                        treated seeds      SRS23110262
# 4                                        treated seeds      SRS23110261
# ..                                                 ...              ...
# 431  Drought-responsive small RNAs in Sorghum bicol...        ERS239305
# 432  Drought-responsive small RNAs in Sorghum bicol...        ERS239304
# 433  Drought-responsive small RNAs in Sorghum bicol...        ERS239303
# 434  Drought-responsive small RNAs in Sorghum bicol...        ERS239302
# 435                                                NaN        SRS269136
#
#     run_accession  Total Size   Submitter  \
# 0     SRR31231318  1882919550  SRA2001949
# 1     SRR31231319  1851542395  SRA2001949
# 2     SRR31231320  1893113189  SRA2001949
# 3     SRR31231321  1787584416  SRA2001949
# 4     SRR31231322  1982273902  SRA2001949
# ..            ...         ...         ...
# 431     ERR266128   374391067   ERA208090
# 432     ERR266129   449970914   ERA208090
# 433     ERR266127   415274994   ERA208090
# 434     ERR266130   373368895   ERA208090
# 435     SRR358900   790526317   SRA047355
#
#                                                 Center  \
# 0           Xingjiang Academy of Agricultural Sciences
# 1           Xingjiang Academy of Agricultural Sciences
# 2           Xingjiang Academy of Agricultural Sciences
# 3           Xingjiang Academy of Agricultural Sciences
# 4           Xingjiang Academy of Agricultural Sciences
# ..                                                 ...
# 431  National Bureau of Plant Genetic Resources, Ne...
# 432  National Bureau of Plant Genetic Resources, Ne...
# 433  National Bureau of Plant Genetic Resources, Ne...
# 434  National Bureau of Plant Genetic Resources, Ne...
# 435                                                GEO
#
#                                                Contact   Experiment  \
# 0                                               YUE Li  SRX26611583
# 1                                               YUE Li  SRX26611582
# 2                                               YUE Li  SRX26611581
# 3                                               YUE Li  SRX26611580
# 4                                               YUE Li  SRX26611579
# ..                                                 ...          ...
# 431                                       ArrayExpress    ERX240648
# 432                                       ArrayExpress    ERX240647
# 433                                       ArrayExpress    ERX240646
# 434                                       ArrayExpress    ERX240645
# 435  Gene Expression Omnibus (GEO), NCBI, NLM, NIH,...    SRX103385
#
#          Study         Organism  ...  Library Source Library Selection  \
# 0    SRP543294  Sorghum bicolor  ...  TRANSCRIPTOMIC            RANDOM
# 1    SRP543294  Sorghum bicolor  ...  TRANSCRIPTOMIC            RANDOM
# 2    SRP543294  Sorghum bicolor  ...  TRANSCRIPTOMIC            RANDOM
# 3    SRP543294  Sorghum bicolor  ...  TRANSCRIPTOMIC            RANDOM
# 4    SRP543294  Sorghum bicolor  ...  TRANSCRIPTOMIC            RANDOM
# ..         ...              ...  ...             ...               ...
# 431  ERP002522  Sorghum bicolor  ...  TRANSCRIPTOMIC            RANDOM
# 432  ERP002522  Sorghum bicolor  ...  TRANSCRIPTOMIC            RANDOM
# 433  ERP002522  Sorghum bicolor  ...  TRANSCRIPTOMIC            RANDOM
# 434  ERP002522  Sorghum bicolor  ...  TRANSCRIPTOMIC            RANDOM
# 435  SRP009100  Sorghum bicolor  ...  TRANSCRIPTOMIC             other
#
#     Library Layout    Bioproject     Biosample Run Accession Run Spots  \
# 0           PAIRED  PRJNA1180449  SAMN44415016           NaN       NaN
# 1           PAIRED  PRJNA1180449  SAMN44415015           NaN       NaN
# 2           PAIRED  PRJNA1180449  SAMN44415014           NaN       NaN
# 3           PAIRED  PRJNA1180449  SAMN44415013           NaN       NaN
# 4           PAIRED  PRJNA1180449  SAMN44415012           NaN       NaN
# ..             ...           ...           ...           ...       ...
# 431         SINGLE     PRJEB1849  SAMEA2065629           NaN       NaN
# 432         SINGLE     PRJEB1849  SAMEA2065628           NaN       NaN
# 433         SINGLE     PRJEB1849  SAMEA1969582           NaN       NaN
# 434         SINGLE     PRJEB1849  SAMEA2065467           NaN       NaN
# 435         SINGLE   PRJNA149413  SAMN00744436           NaN       NaN
#
#      Run Bases  Create Date  Update Date
# 0          NaN   2024/11/05   2024/11/05
# 1          NaN   2024/11/05   2024/11/05
# 2          NaN   2024/11/05   2024/11/05
# 3          NaN   2024/11/05   2024/11/05
# 4          NaN   2024/11/05   2024/11/05
# ..         ...          ...          ...
# 431        NaN   2014/05/14   2014/08/12
# 432        NaN   2014/05/14   2014/08/12
# 433        NaN   2014/05/14   2014/08/12
# 434        NaN   2014/05/14   2014/08/12
# 435        NaN   2015/10/25   2014/06/17
#
# [436 rows x 22 columns]

# %%
joined.loc[:,['run_accession', 'Bioproject', "Library Strategy", "Library Layout"]].to_csv("sorghum_runs_projects_merged_filtered.csv", index=False)

# %%
# Out:
#   experiment_accession experiment_alias  \
# 0          SRX26611583           GL98D1
# 1          SRX26611582           GL98C3
# 2          SRX26611581           GL98C2
# 3          SRX26611580           GL98C1
# 4          SRX26611579          GL220B3
#
#                                                title study_accession  \
# 0  Metabolomic and Transcriptomic Analysis of Dro...       SRP543294
# 1  Metabolomic and Transcriptomic Analysis of Dro...       SRP543294
# 2  Metabolomic and Transcriptomic Analysis of Dro...       SRP543294
# 3  Metabolomic and Transcriptomic Analysis of Dro...       SRP543294
# 4  Metabolomic and Transcriptomic Analysis of Dro...       SRP543294
#
#   design_description sample_accession library_strategy library_layout  \
# 0      treated seeds      SRS23110265          RNA-Seq         PAIRED
# 1      treated seeds      SRS23110264          RNA-Seq         PAIRED
# 2      treated seeds      SRS23110263          RNA-Seq         PAIRED
# 3      treated seeds      SRS23110262          RNA-Seq         PAIRED
# 4      treated seeds      SRS23110261          RNA-Seq         PAIRED
#
#         instrument_model run_accession  ...  Library Source  \
# 0  Illumina NovaSeq 6000   SRR31231318  ...  TRANSCRIPTOMIC
# 1  Illumina NovaSeq 6000   SRR31231319  ...  TRANSCRIPTOMIC
# 2  Illumina NovaSeq 6000   SRR31231320  ...  TRANSCRIPTOMIC
# 3  Illumina NovaSeq 6000   SRR31231321  ...  TRANSCRIPTOMIC
# 4  Illumina NovaSeq 6000   SRR31231322  ...  TRANSCRIPTOMIC
#
#    Library Selection  Library Layout    Bioproject     Biosample  \
# 0             RANDOM          PAIRED  PRJNA1180449  SAMN44415016
# 1             RANDOM          PAIRED  PRJNA1180449  SAMN44415015
# 2             RANDOM          PAIRED  PRJNA1180449  SAMN44415014
# 3             RANDOM          PAIRED  PRJNA1180449  SAMN44415013
# 4             RANDOM          PAIRED  PRJNA1180449  SAMN44415012
#
#    Run Accession  Run Spots  Run Bases  Create Date Update Date
# 0            NaN        NaN        NaN   2024/11/05  2024/11/05
# 1            NaN        NaN        NaN   2024/11/05  2024/11/05
# 2            NaN        NaN        NaN   2024/11/05  2024/11/05
# 3            NaN        NaN        NaN   2024/11/05  2024/11/05
# 4            NaN        NaN        NaN   2024/11/05  2024/11/05
#
# [5 rows x 37 columns]
